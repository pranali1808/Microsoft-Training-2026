# %%
print('''welcome to
nirman
hello how are
you''')
# Out:
# welcome to
# nirman
# hello how are
# you

# %%
a=10.2
b=int(a)
#b=a
print(b)
# Out:
# 10

# %%
list=[10,20,34,56,]
print(list)
print(type(list))
print(id(list))
print(id(b))
# Out:
# [10, 20, 34, 56]
# <class 'list'>
# 133187600306496
# 11645640

# %%
a=[10,20,30,40]
a[1]=30
print(a)
# Out:
# [10, 30, 30, 40]

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
def Greet():
   print("wellcome to nirman")
Greet()
Greet()
# Out:
# wellcome to nirman
# wellcome to nirman
